# %% [markdown]
# ### Задача №1

# %% [markdown]
# На рисунке схема дорог N-ского района изображена в виде графа, в таблице содержатся сведения о протяжённости каждой из этих дорог (в километрах).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Так как таблицу и схему рисовали независимо друг от друга, то нумерация населённых пунктов в таблице никак не связана с буквенными обозначениями на графе.
#
# **Определите, какова сумма протяжённостей дорог из пункта B в пункт A и из пункта H в пункт F.**

# %% [markdown]
# <details>
#   <summary>Ответ</summary>
#   42
# </details>

# %% [markdown]
# ### Задача №2

# %% [markdown]
# Миша заполнял таблицу истинности функции:
#  F = (w → ¬(x → y)) ∨ z, но успел заполнить лишь фрагмент из четырёх различных её строк, даже не указав, какому столбцу таблицы соответствует каждая из переменных.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Определите, какому столбцу таблицы истинности функции F соответствует каждая из переменных x, y, z, w.**

# %% [markdown]
# <details>
#   <summary>Ответ</summary>
#   wyxz
# </details>

# %% [markdown]
# ### Задача №3

# %% [markdown]
# На рисунке приведена схема указанной базы данных.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Используя информацию из приведённой базы данных, **определите общую выручку (в руб.), полученную от продажи всех видов салфеток магазинами на улице Пушкинская за период с 7 по 12 июня включительно.**

# %% [markdown]
# <details>
#   <summary>Ответ</summary>
#   55050
# </details>

# %% [markdown]
# ### Задача №4

# %% [markdown]
# По каналу связи передаются шифрованные сообщения, содержащие только десять букв: А, Б, Е, И, К, Л, Р, С, Т, У; для передачи используется неравномерный двоичный код. Для кодирования букв используются кодовые слова, представленные в таблице.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Укажите кратчайшее кодовое слово для буквы С, при котором код будет удовлетворять условию Фано.** Если таких кодов несколько, укажите код с наименьшим числовым значением

# %% [markdown]
# <details>
#   <summary>Ответ</summary>
#   1110
# </details>

# %% [markdown]
# ### Задача №5

# %% [markdown]
# На вход алгоритма подаётся натуральное число N. Алгоритм строит по нему новое число R следующим образом.
#
# 1. Строится двоичная запись числа N.
# 2. Далее эта запись обрабатывается по следующему правилу:
# а) если сумма цифр в двоичной записи числа чётная, то к этой записи справа дописывается 0, а затем три левых разряда заменяются на 111;
# б) если сумма цифр в двоичной записи числа нечётная, то к этой записи справа дописывается 1, а затем два левых разряда заменяются на 10.
# Полученная таким образом запись является двоичной записью искомого числа R.
#
# **Укажите минимальное число N, после обработки которого с помощью этого алгоритма получается число R, большее 58.**

# %% [markdown]
# <details>
#   <summary>Ответ</summary>
#   18
# </details>

# %% [markdown]
# ### Задача №6

# %% [markdown]
# Черепаха умеет двигаться по координатной плоскости и рисовать. </br>
# Начинает движение из точки (0;0) и смотрит вверх. Хвост опущен.

# %% [markdown]
# Команды:
# опустить/поднять хвост — начать/перестать рисовать</br>
# вперед(n)/назад(n) — пройти на n шагов вперед/назад по направлению движения</br>
# направо(k)/налево(k) — повернуть вправо/влево на k градусов</br>
# повтори x [...] — повторить x раз действия в скобках</br>

# %% [markdown]
# Черепахе был дан для исполнения следующий алгоритм:
#
# *   Новый пункт
# *   Новый пункт
#
#
# Направо 315 Повтори 12 [Вперёд 11 Направо 45].
#
# **Определите периметр фигуры, нарисованной в результате работы данного алгоритма. **

# %% [markdown]
# <details>
#   <summary>Ответ</summary>
#   88
# </details>

# %% [markdown]
# ### Задача №7

# %% [markdown]
# В студии звукозаписи записываются музыкальные фрагменты (аудиодорожки) в формате стерео (двухканальная запись) с частотой дискретизации 198 кГц  и 36-битным разрешением, длительностью 2 минуты 10 секунд. Аудиодорожки сохраняются в памяти компьютера, группируются в папки по 375 шт., затем передаются по каналу связи с пропускной способностью передачи данных  9 309 050 бит/с. **Сколько секунд требуется для передачи одного полного пакета аудиодорожек?**

# %% [markdown]
# <details>
#   <summary>Ответ</summary>
#   74656
# </details>

# %% [markdown]
# ### Задача №8

# %% [markdown]
# Все пятибуквенные слова, составленные из букв К, О, Ф, Е, записаны в алфавитном порядке и пронумерованы.
#
# Вот начало списка:
# 1.  ЕЕЕЕЕ
# 2.  ЕЕЕЕК
# 3.  ЕЕЕЕО
# 4.  ЕЕЕЕФ
# 5.  ЕЕЕКЕ …
#
# **Под каким номером в списке идёт последнее слово, которое не содержит букв Е и содержит ровно одну букву Ф?**

# %% [markdown]
# <details>
#   <summary>Ответ</summary>
#   939
# </details>

# %% [markdown]
# ### Задача №9

# %% [markdown]
# Откройте файл электронной таблицы, содержащей в каждой строке четыре натуральных числа.
#
# **Определите количество строк таблицы, в которых все числа различны, при этом сумма наибольшего и наименьшего чисел меньше суммы двух оставшихся. **

# %% [markdown]
# <details>
#   <summary>Ответ</summary>
#   7387
# </details>

# %% [markdown]
# ### Задача №10

# %% [markdown]
# С помощью текстового редактора определите, **сколько раз встречается сочетание
# букв «рук» или «Рук»** в тексте глав IV, V, VI и VII второй части тома 2 романа Л.Н. Толстого «Война и мир». В ответе укажите только число

# %% [markdown]
# <details>
#   <summary>Ответ</summary>
#   12
# </details>

# %% [markdown]
# ### Задача №11

# %% [markdown]
# На предприятии каждой изготовленной детали присваивают серийный номер, состоящий из 1224 символов. В базе данных для хранения каждого серийного номера отведено одинаковое и минимально возможное число байт. При этом используется посимвольное кодирование серийных номеров, все символы кодируются одинаковым и минимально возможным числом бит. Известно, что для хранения 16 535 серийных номеров отведено не более 13 Мбайт памяти. **Определите максимально возможную мощность алфавита, используемого для записи серийных номеров. **

# %% [markdown]
# <details>
#   <summary>Ответ</summary>
#   32
# </details>

# %% [markdown]
# ### Задача №12

# %% [markdown]
# Исполнитель Редактор преобразовывает строку цифр при помощи двух функций:
#
# А) заменить (v, w)
# Эта команда заменяет в строке первое слева вхождение цепочки v на цепочку w.
# Б) нашлось (v)
# Эта команда проверяет, встречается ли цепочка v в строке исполнителя Редактор.

# %% [markdown]
# **Какая строка получится в результате применения приведённой ниже программы к строке, состоящей из 108 идущих подряд цифр 7?** В ответе запишите полученную строку.
#
# <pre>
# НАЧАЛО ПОКА нашлось (33333) ИЛИ нашлось (777)
#     ЕСЛИ нашлось (33333)
#     ТО заменить (33333, 7)
#     ИНАЧЕ заменить (777, 3)
#     КОНЕЦ ЕСЛИ
# КОНЕЦ ПОКА
# КОНЕЦ
# </pre>

# %% [markdown]
# <details>
#   <summary>Ответ</summary>
#   3337
# </details>

# %% [markdown]
# ### Задача №13

# %% [markdown]
# Сеть задана IP-адресом 103.161.48.0 и сетевой маской 255.255.240.0.
# Сколько в этой сети IP-адресов, для которых количество единиц в двоичной записи IPадреса кратно 2?

# %% [markdown]
# <details>
#   <summary>Ответ</summary>
#   2048
# </details>

# %% [markdown]
# ### Задача №14

# %% [markdown]
# Значение арифметического выражения 4**100 – х, где х – целое положительное число, не превышающее 2030, записали в 4-ричной системе счисления.
#
# **Определите наименьшее значение х**, при котором в 4-ричной записи числа, являющегося значением данного арифметического выражения, содержится ровно три нуля.

# %% [markdown]
# <details>
#   <summary>Ответ</summary>
#   64
# </details>

# %% [markdown]
# ### Задача №15

# %% [markdown]
# Обозначим через ДЕЛ(n, m) утверждение «натуральное число n делится без остатка на натуральное число m».
#
# **Для какого наименьшего натурального числа А** логическое выражение
# (ДЕЛ(x, 2) → ¬ДЕЛ(x, 5)) ∨ (x + A ≥ 70)
# истинно (т.е. принимает значение 1) при любом целом положительном значении переменной х?

# %% [markdown]
# <details>
#   <summary>Ответ</summary>
#   60
# </details>

# %% [markdown]
# ### Задача №16

# %% [markdown]
# Алгоритм вычисления значения функции F(n), где n –– натуральное число, задан следующими соотношениями:
# <pre>F(n) = 1 при n = 1;
# F(n) = n × F(n – 1), если n > 1.
# </pre>
# **Чему равно значение выражения (F(2025) / 5 + F(2023)) / F(2021)?**

# %% [markdown]
# <details>
#   <summary>Ответ</summary>
#   3353073668826
# </details>

# %% [markdown]
# ### Задача №17

# %% [markdown]
# В файле содержится последовательность целых чисел, каждое из которых по модулю не превышает 100 000. Определите количество пар элементов последовательности, в которых два числа равны, а сумма чисел меньше количества чётных элементов последовательности.
#
# **В ответе запишите количество найденных пар чисел, затем максимальную из сумм элементов таких пар. **

# %% [markdown]
# <details>
#   <summary>Ответ</summary>
#   1  10620
# </details>

# %% [markdown]
# ### Задача №18

# %% [markdown]
# Робот может перемещаться на одну клетку вправо или вниз. Сквозь стены Робот пройти не может. </br>
# Если Робот не может продолжить движение - клетка считается итоговой.
# **Определите минимальную и максимальную суммы в итоговой клетке.**

# %% [markdown]
# <details>
#   <summary>Ответ</summary>
#   1476  2466
# </details>

# %% [markdown]
# ### Задача №19

# %% [markdown]
# Два игрока, Петя и Ваня, играют в следующую игру. Перед игроками лежит куча камней. Игроки ходят по очереди, первый ход делает Петя.
#
# За один ход игрок может: убрать из кучи два камня или убрать из кучи пять камней или уменьшить количество камней в куче в два раза (количество камней, полученное при делении, округляется до меньшего).
#
# Например, из кучи в 20 камней за один ход можно получить кучу из 18, 15 или 10 камней.
# Игра завершается, когда количество камней в куче становится не более 24.
# Победителем считается игрок, сделавший последний ход, то есть первым получивший кучу, в которой будет 24 или меньше камней.
#
# В начальный момент в куче было S камней, S ≥ 25. Будем говорить, что игрок имеет выигрышную стратегию, если он может выиграть при любых ходах противника.
#
# **Укажите минимальное значение S**, при котором Петя не может выиграть за один ход, но при любом ходе Пети Ваня может выиграть своим первым ходом.

# %% [markdown]
# <details>
#   <summary>Ответ</summary>
#   50
# </details>

# %% [markdown]
# ### Задача №20

# %% [markdown]
# Для игры, описанной в задании 19, **найдите два наименьших значения S**, при которых у Пети есть выигрышная стратегия, причём одновременно выполняются два условия:
# − Петя не может выиграть за один ход;
# − Петя может выиграть своим вторым ходом независимо от того, как будет ходить Ваня.
#
# Найденные значения запишите в ответе в порядке возрастания.

# %% [markdown]
# <details>
#   <summary>Ответ</summary>
#   52  53
# </details>

# %% [markdown]
# ### Задача №21

# %% [markdown]
# Для игры, описанной в задании 19, **найдите минимальное значение S**, при котором одновременно выполняются два условия:
# – у Вани есть выигрышная стратегия, позволяющая ему выиграть первым или вторым ходом при любой игре Пети;
# – у Вани нет стратегии, которая позволит ему гарантированно выиграть первым ходом.

# %% [markdown]
# <details>
#   <summary>Ответ</summary>
#   64
# </details>

# %% [markdown]
# ### Задача №22

# %% [markdown]
# **Определите минимальное время, через которое завершится выполнение всей совокупности процессов**, при условии, что все независимые друг от друга процессы могут выполняться параллельно

# %%
input_3 = None

# %% [markdown]
# <details>
#   <summary>Ответ</summary>
#   3032
# </details>

# %% [markdown]
# ### Задача №23

# %% [markdown]
# Исполнитель преобразует число на экране.
# У исполнителя есть три команды, которые обозначены латинскими буквами:
# A. Умножить на 3
# B. Прибавить 2
# C. Прибавить 4 </br>
# Программа для исполнителя – это последовательность команд.
#
# **Сколько существует программ, для которых при исходном числе 4 результатом является число 36, и при этом траектория вычислений не содержит числа 33 и 35 одновременно? **

# %% [markdown]
# <details>
#   <summary>Ответ</summary>
#   1926
# </details>

# %% [markdown]
# ### Задача №24

# %% [markdown]
# Текстовый файл состоит из символов A, B, C, D и E и цифры от 1 до 9 включительно.
#
# **Определите максимальную длину непрерывной последовательности символов в прилагаемом файле, состоящая из троек BCA, между которыми стоит ровно одна произвольная цифра.**

# %% [markdown]
# <details>
#   <summary>Ответ</summary>
#   15
# </details>

# %% [markdown]
# ### Задача №25

# %% [markdown]
# Пусть S – сумма всех натуральных делителей целого числа, не считая самого числа.
#
# **Напишите программу, которая перебирает целые числа, бóльшие 320 000, в порядке возрастания и ищет среди них такие, для которых значение S не является простым числом.**
#
# В ответе запишите в первом столбце таблицы первые шесть найденных чисел в порядке возрастания, а во втором столбце для каждого из них – значение S.
#
# Например, для числа 10 S = 1 + 2 + 5 = 8.

# %% [markdown]
# <details>
#   <summary>Ответ</summary>
#   320001  145503</br>
#   320002  160004 </br>
#   320003  3397 </br>
#   320004  509916 </br>
#   320005  131579 </br>
#   320006  179350
# </details>

# %% [markdown]
# ### Задача №26

# %% [markdown]
# По результатам зачётной и экзаменационной сессии студенты получили отметку «зачтены» при сдаче всех зачётов или «не зачтены» при не сдаче одного из зачётов, а также три отметки за экзамены. Сессия считается закрытой в случае получения отметки «3» и выше по каждому экзамену, и при этом полученной отметки «зачтено» по всем зачётам.
#
# Среди студентов определяются обучающиеся, имеющие академическую задолженность (то есть студенты с не закрытой сессией). Для одного из студентов с не закрытой сессией по причине не набранного необходимого балла по одному из экзаменов деканат предоставляет возможность пересдать этот предмет. Если таких студентов несколько, выбирается тот, кто получил отметку «зачтены» по зачетам. Если и таких студентов несколько – выбирается студент с наибольшей суммой отметок по всем экзаменам.
#
# Гарантируется, что есть ровно один студент, подходящий под требования деканата.  Необходимо найти количество студентов с академической задолженностью, а также ID искомого студента со всеми сданными зачётами и не сданным одним экзаменом.
#
# Входные данные
# В первой строке входного файла находится число N – количество студентов (натуральное число, не превышающее 1000). Каждая из следующих N строк содержит четыре числа: ID студента (натуральное число, не превышающее 10 000), соответственно три оценки по экзаменам по балльной шкале (одно из чисел 2, 3, 4 или 5) и итоговая отметка за зачёты (1 обозначает отметку «зачтены», 0 – отметку «не зачтены»).
#
# Запишите в ответе два целых числа: сначала количество студентов с академической задолженностью, а затем ID искомого студента со всеми сданными зачётами и не сданным одним экзаменом.
#
# Типовой пример организации данных во входном файле </br>
# 6 </br>
# 1 2 3 4 1 </br>
# 3 3 4 5 1 </br>
# 5 4 5 5 1  </br>
# 8 5 4 4 0 </br>
# 4 2 2 3 0 </br>
# 11 2 5 5 1 </br>
#
# При таких входных данных 4 студента имеют академическую задолженность. Из них с одной «двойкой» и сданными зачётами являются студенты с ID 1 и 11. Студент с ID=11 имеет наибольшую сумму баллов за экзамены, поэтому получит возможность закрытия задолженности.

# %% [markdown]
# <details>
#   <summary>Ответ</summary>
#   303  88455771
# </details>

# %% [markdown]
# ### Задача №27

# %% [markdown]
# Фрагмент звёздного неба спроецирован на плоскость с декартовой системой координат. Учёный решил провести кластеризацию полученных точек, являющихся изображениями звёзд, то есть разбить их множество на N непересекающихся непустых подмножеств (кластеров), таких что точки каждого подмножества лежат внутри прямоугольника со сторонами длиной H и W, причём эти прямоугольники между собой не пересекаются. Стороны прямоугольников не обязательно параллельны координатным осям.
#
# Гарантируется, что такое разбиение существует и единственно для заданных размеров прямоугольников.
#
# Будем называть центром кластера точку этого кластера, сумма расстояний от которой до всех остальных точек кластера минимальна. Для каждого кластера гарантируется единственность его центра. Расстояние между двумя точками на плоскости 𝐴(𝑥1,𝑦1) и 𝐵(𝑥2,𝑦2) вычисляется по формуле:  ![image.png](data:image/png;base64,...)
#
# В файле А хранятся данные о звёздах трёх кластеров, где Н=4, W=4 для  каждого кластера. В каждой строке записана информация о расположении на карте одной звезды: сначала координата х, затем координата у. Значения даны в условных единицах. Известно, что количество звёзд не превышает 1000.
#
# В файле Б хранятся данные о звёздах четырёх кластеров, где Н=4, W=4 для каждого кластера. Известно, что количество звёзд не превышает 10 000.
# Структура хранения информации о звездах в файле Б аналогична файлу А.
#
# Для каждого файла определите координаты центра каждого кластера, затем вычислите два числа: Pх – среднее арифметическое абсцисс центров кластеров, и Py – среднее арифметическое ординат центров кластеров.
#
# В ответе запишите четыре числа: в первой строке сначала целую часть произведения |Pх| × 10 000, затем целую часть произведения |Py| × 10 000 для файла А, во второй строке – аналогичные данные для файла Б.

# %% [markdown]
# <details>
#   <summary>Ответ</summary>
#   6494 22451 </br>
#  25557 5810
# </details>
